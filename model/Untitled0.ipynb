# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp '/content/drive/My Drive/Colab Notebooks/sem9_minipro/aishwaryakp/FDHN/model/2.1.BT+TC+CB.py' .
# Out:
# cp: cannot stat '/content/drive/My Drive/Colab Notebooks/sem9_minipro/aishwaryakp/FDHN/model/2.1.BT+TC+CB.py': No such file or directory

# %%
# !pip install transformers
# !pip install torch torchvision

# %%
# !python 2.1.BT+TC+CB.py
# Out:
# 2024-12-14 03:43:27.465977: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-14 03:43:27.521902: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-14 03:43:27.537349: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-14 03:43:27.589252: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/sem9_minipro/aishwaryakp/FDHN/LIAR"
# Out:
# README	test.tsv  train.tsv  valid.tsv
